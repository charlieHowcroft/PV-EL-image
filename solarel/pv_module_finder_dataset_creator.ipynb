# %%
from image_processor import fix_barrel_distortion, random_image
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

# %%
folder_name = "raw_images_module_finder"
image_folders = ["C:/Users/chuck/OneDrive/Desktop/Honors/M0060/M0060",
            "C:/Users/chuck/OneDrive/Desktop/Honors/BT1/BT1"]
toml_path = "C:/Users/chuck/OneDrive/Desktop/Honors/solarEL/solarel/configs/camera_config.toml"

file_names = []
for folder_path in image_folders:
    for file_name in os.listdir(folder_path):
        if os.path.isfile(os.path.join(folder_path, file_name)):
            file_names.append(os.path.join(folder_path, file_name))

folder_path = os.path.join(os.getcwd(), folder_name)
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

for i, image_path in enumerate(file_names):
    print(image_path)
    img = cv2.imread(image_path, 0)
    img = fix_barrel_distortion(img, toml_path)
    img = cv2.pyrDown(img)
    img = cv2.pyrDown(img)
    cv2.imwrite(os.path.join(folder_path, f"image_{i}.jpg"), img)
# Out:
# C:/Users/chuck/OneDrive/Desktop/Honors/M0060/M0060\LRE504055180800401088_IMG_8667.JPG
# C:/Users/chuck/OneDrive/Desktop/Honors/M0060/M0060\LRE504055180800401279_IMG_8749.JPG
# C:/Users/chuck/OneDrive/Desktop/Honors/M0060/M0060\LRP504033180800402204_IMG_8693.JPG
# C:/Users/chuck/OneDrive/Desktop/Honors/M0060/M0060\LRP504033180800404028_IMG_8747.JPG
# C:/Users/chuck/OneDrive/Desktop/Honors/M0060/M0060\LRP504033180800404040_IMG_8740.JPG
# C:/Users/chuck/OneDrive/Desktop/Honors/M0060/M0060\LRP504033180800404041_IMG_8744.JPG
# C:/Users/chuck/OneDrive/Desktop/Honors/M0060/M0060\LRP504033180800404133_IMG_8742.JPG
# C:/Users/chuck/OneDrive/Desktop/Honors/M0060/M0060\LRP504033180800404423_IMG_8644.JPG
# C:/Users/chuck/OneDrive/Desktop/Honors/M0060/M0060\LRP504033180800404429_IMG_8642.JPG
# C:/Users/chuck/OneDrive/Desktop/Honors/M0060/M0060\LRP504033180800404540_IMG_8646.JPG
# C:/Users/chuck/OneDrive/Desktop/Honors/M0060/M0060\LRP504033180800404561_IMG_8645.JPG
# ...
